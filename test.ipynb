# %%
import CFL
import imp
imp.reload(CFL)

grammarFile = open("grammar.txt", "r")
cfl = CFL.ContextFreeLanguage()

while True:
    line = grammarFile.readline()
    if line == "":
        break
    [L,R] = line[:-1].split('-->')
    print("input", L, R)
    cfl.addRule(L, R)
cfl.addRule("[S_p]", "[S]")
cfl.addStarter("[S_p]")
cfl.addEnder('"#"')
cfl.init()
# Out:
# input [S]   [funcs]
# new Rule: [S] --> [[funcs] ]
# input [S]   [func] [funcs]
# new Rule: [S] --> [[func] [funcs] ]
# input [funcs]   [func]
# new Rule: [funcs] --> [[func] ]
# input [funcs]   [func] [funcs]
# new Rule: [funcs] --> [[func] [funcs] ]
# input [func]   [type] "IDN" "(" ")" [func_body]
# new Rule: [func] --> [[type] "IDN" "(" ")" [func_body] ]
# input [func]   [type] "IDN" "(" [args] ")" [func_body]
# new Rule: [func] --> [[type] "IDN" "(" [args] ")" [func_body] ]
# input [type]   "int"
# new Rule: [type] --> ["int" ]
# input [type]   "char"
# new Rule: [type] --> ["char" ]
# input [type]   "float"
# new Rule: [type] --> ["float" ]
# input [type]   "void"
# new Rule: [type] --> ["void" ]
# input [args]   [type] "IDN"
# new Rule: [args] --> [[type] "IDN" ]
# input [args]   [type] "IDN" [arg]
# new Rule: [args] --> [[type] "IDN" [arg] ]
# input [arg]   "," [type] "IDN"
# new Rule: [arg] --> ["," [type] "IDN" ]
# input [arg]   "," [type] "IDN" [arg]
# new Rule: [arg] --> ["," [type] "IDN" [arg] ]
# input [func_body]   ";"
# new Rule: [func_body] --> [";" ]
# input [func_body]   [block]
# new Rule: [func_body] --> [[block] ]
# input [block]   "{" "}"
# new Rule: [block] --> ["{" "}" ]
# input [block]   "{" [define_stmts] "}"
# new Rule: [block] --> ["{" [define_stmts] "}" ]
# input [block]   "{" [stmts] "}"
# new Rule: [block] --> ["{" [stmts] "}" ]
# input [block]   "{" [define_stmts] [stmts] "}"
# new Rule: [block] --> ["{" [define_stmts] [stmts] "}" ]
# input [define_stmts]   [define_stmt]
# new Rule: [define_stmts] --> [[define_stmt] ]
# input [define_stmts]   [define_stmt] [define_stmts]
# new Rule: [define_stmts] --> [[define_stmt] [define_stmts] ]
# input [define_stmt]   [type] "IDN" [init] [vars] ";"
# new Rule: [define_stmt] --> [[type] "IDN" [init] [vars] ";" ]
# input [define_stmt]   [type] "IDN" [vars] ";"
# new Rule: [define_stmt] --> [[type] "IDN" [vars] ";" ]
# input [define_stmt]   [type] "IDN" [init]  ";"
# new Rule: [define_stmt] --> [[type] "IDN" [init] ";" ]
# input [define_stmt]   [type] "IDN" ";"
# new Rule: [define_stmt] --> [[type] "IDN" ";" ]
# input [init]   "=" [expression]
# new Rule: [init] --> ["=" [expression] ]
# input [init]   "[" "INT10" "]"
# new Rule: [init] --> ["[" "INT10" "]" ]
# input [vars]   "," "IDN" [init] [vars]
# new Rule: [vars] --> ["," "IDN" [init] [vars] ]
# input [vars]   "," "IDN" [vars]
# new Rule: [vars] --> ["," "IDN" [vars] ]
# input [vars]   "," "IDN" [init]
# new Rule: [vars] --> ["," "IDN" [init] ]
# input [vars]   "," "IDN"
# new Rule: [vars] --> ["," "IDN" ]
# input [stmts]   [stmt]
# new Rule: [stmts] --> [[stmt] ]
# input [stmts]   [stmt] [stmts]
# new Rule: [stmts] --> [[stmt] [stmts] ]
# input [stmt]   [assign_stmt]
# new Rule: [stmt] --> [[assign_stmt] ]
# input [stmt]   [jump_stmt]
# new Rule: [stmt] --> [[jump_stmt] ]
# input [stmt]   [iteration_stmt]
# new Rule: [stmt] --> [[iteration_stmt] ]
# input [stmt]   [branch_stmt]
# new Rule: [stmt] --> [[branch_stmt] ]
# input [assign_stmt]   [expression] ";"
# new Rule: [assign_stmt] --> [[expression] ";" ]
# input [jump_stmt]   "continue" ";"
# new Rule: [jump_stmt] --> ["continue" ";" ]
# input [jump_stmt]   "break" ";"
# new Rule: [jump_stmt] --> ["break" ";" ]
# input [jump_stmt]   "return" [isnull_expr] ";"
# new Rule: [jump_stmt] --> ["return" [isnull_expr] ";" ]
# input [jump_stmt]   "return" ";"
# new Rule: [jump_stmt] --> ["return" ";" ]
# input [iteration_stmt]   "while" "(" [logical_expression] ")" [block_stmt]
# new Rule: [iteration_stmt] --> ["while" "(" [logical_expression] ")" [block_stmt] ]
# input [iteration_stmt]   "for" "(" [isnull_expr] ";" [isnull_expr] ";" [isnull_expr] ")" [block_stmt]
# new Rule: [iteration_stmt] --> ["for" "(" [isnull_expr] ";" [isnull_expr] ";" [isnull_expr] ")" [block_stmt] ]
# input [iteration_stmt]   "do" [block_stmt] "while" "(" [logical_expression] ")" ";"
# new Rule: [iteration_stmt] --> ["do" [block_stmt] "while" "(" [logical_expression] ")" ";" ]
# input [branch_stmt]   "if" "(" [logical_expression] ")" [block_stmt] [result]
# new Rule: [branch_stmt] --> ["if" "(" [logical_expression] ")" [block_stmt] [result] ]
# input [branch_stmt]   "if" "(" [logical_expression] ")" [block_stmt]
# new Rule: [branch_stmt] --> ["if" "(" [logical_expression] ")" [block_stmt] ]
# input [result]   "else" [block_stmt]
# new Rule: [result] --> ["else" [block_stmt] ]
# input [logical_expression]   "!" [expression] [bool_expression]
# new Rule: [logical_expression] --> ["!" [expression] [bool_expression] ]
# input [logical_expression]   [expression] [bool_expression]
# new Rule: [logical_expression] --> [[expression] [bool_expression] ]
# input [bool_expression]   [lop] [expression] [bool_expression]
# new Rule: [bool_expression] --> [[lop] [expression] [bool_expression] ]
# input [logical_expression]   "!" [expression]
# new Rule: [logical_expression] --> ["!" [expression] ]
# input [logical_expression]   [expression]
# new Rule: [logical_expression] --> [[expression] ]
# input [bool_expression]   [lop] [expression]
# new Rule: [bool_expression] --> [[lop] [expression] ]
# input [lop]   "&&"
# new Rule: [lop] --> ["&&" ]
# input [lop]   "||"
# new Rule: [lop] --> ["||" ]
# input [block_stmt]   "{" [stmts] "}"
# new Rule: [block_stmt] --> ["{" [stmts] "}" ]
# input [block_stmt]   "{" "}"
# new Rule: [block_stmt] --> ["{" "}" ]
# input [isnull_expr]   [expression]
# new Rule: [isnull_expr] --> [[expression] ]
# input [expression]   [value] [operation]
# new Rule: [expression] --> [[value] [operation] ]
# input [expression]   [value]
# new Rule: [expression] --> [[value] ]
# input [operation]   [compare_op] [value]
# new Rule: [operation] --> [[compare_op] [value] ]
# input [operation]   [equal_op] [value]
# new Rule: [operation] --> [[equal_op] [value] ]
# input [compare_op]   ">"
# new Rule: [compare_op] --> [">" ]
# input [compare_op]   ">="
# new Rule: [compare_op] --> [">=" ]
# input [compare_op]   "<"
# new Rule: [compare_op] --> ["<" ]
# input [compare_op]   "<="
# new Rule: [compare_op] --> ["<=" ]
# input [compare_op]   "=="
# new Rule: [compare_op] --> ["==" ]
# input [compare_op]   "!="
# new Rule: [compare_op] --> ["!=" ]
# input [equal_op]   "="
# new Rule: [equal_op] --> ["=" ]
# input [equal_op]   "+="
# new Rule: [equal_op] --> ["+=" ]
# input [equal_op]   "-="
# new Rule: [equal_op] --> ["-=" ]
# input [equal_op]   "*="
# new Rule: [equal_op] --> ["*=" ]
# input [equal_op]   "/="
# new Rule: [equal_op] --> ["/=" ]
# input [equal_op]   "%="
# new Rule: [equal_op] --> ["%=" ]
# input [value]   [item] [value']
# new Rule: [value] --> [[item] [value'] ]
# input [value]   [item]
# new Rule: [value] --> [[item] ]
# input [value']   "+" [item] [value']
# new Rule: [value'] --> ["+" [item] [value'] ]
# input [value']   "+" [item]
# new Rule: [value'] --> ["+" [item] ]
# input [value']   "-" [item] [value']
# new Rule: [value'] --> ["-" [item] [value'] ]
# input [value']   "-" [item]
# new Rule: [value'] --> ["-" [item] ]
# input [item]   [factor] [item']
# new Rule: [item] --> [[factor] [item'] ]
# input [item]   [factor]
# new Rule: [item] --> [[factor] ]
# input [item']   "*" [factor] [item']
# new Rule: [item'] --> ["*" [factor] [item'] ]
# input [item']   "*" [factor]
# new Rule: [item'] --> ["*" [factor] ]
# input [item']   "/" [factor] [item']
# new Rule: [item'] --> ["/" [factor] [item'] ]
# input [item']   "/" [factor]
# new Rule: [item'] --> ["/" [factor] ]
# input [item']   "%" [factor] [item']
# new Rule: [item'] --> ["%" [factor] [item'] ]
# input [item']   "%" [factor]
# new Rule: [item'] --> ["%" [factor] ]
# input [factor]   "(" [value] ")"
# new Rule: [factor] --> ["(" [value] ")" ]
# input [factor]   "IDN" [call_func]
# new Rule: [factor] --> ["IDN" [call_func] ]
# input [factor]   "IDN"
# new Rule: [factor] --> ["IDN" ]
# input [factor]   [const]
# new Rule: [factor] --> [[const] ]
# input [call_func]   "(" [es] ")"
# new Rule: [call_func] --> ["(" [es] ")" ]
# input [call_func]   "(" ")"
# new Rule: [call_func] --> ["(" ")" ]
# input [es]   [isnull_expr] [isnull_es]
# new Rule: [es] --> [[isnull_expr] [isnull_es] ]
# input [es]   [isnull_expr]
# new Rule: [es] --> [[isnull_expr] ]
# input [es]   [isnull_es]
# new Rule: [es] --> [[isnull_es] ]
# input [isnull_es]   "," [isnull_expr]
# new Rule: [isnull_es] --> ["," [isnull_expr] ]
# input [isnull_es]   ","
# new Rule: [isnull_es] --> ["," ]
# input [const]   [num_const]
# new Rule: [const] --> [[num_const] ]
# input [const]   "FLOAT"
# new Rule: [const] --> ["FLOAT" ]
# input [const]   "CHAR"
# new Rule: [const] --> ["CHAR" ]
# input [const]   "STR"
# new Rule: [const] --> ["STR" ]
# input [num_const]   "INT10"
# new Rule: [num_const] --> ["INT10" ]
# input [num_const]   "INT8"
# new Rule: [num_const] --> ["INT8" ]
# input [num_const]   "INT16"
# new Rule: [num_const] --> ["INT16" ]
# new Rule: [S_p] --> [[S] ]
# [S_p]
# "#"

# %%
import scanner
import imp
imp.reload(scanner)


testFile = open("test.cpp", "rb")
flag = True
while True:
    token = scanner.Scanner.scan(testFile)
    cfl.onlineParse(token, flag)
    print(token.elem, token.info)
    flag = False
    if token.info == "":
        break
# Out:
# ---------------------------
# "void"
# "void" void
# ---------------------------
# "IDN"
# [type] --> ["void" ]
# "IDN" func
# ---------------------------
# "("
# "(" (
# ---------------------------
# "int"
# "int" int
# ---------------------------
# "IDN"
# [type] --> ["int" ]
# "IDN" a
# ---------------------------
# ","
# "," ,
# ---------------------------
# "int"
# "int" int
# ---------------------------
# "IDN"
# [type] --> ["int" ]
# "IDN" b
# ---------------------------
# ")"
# [arg] --> ["," [type] "IDN" ]
# [args] --> [[type] "IDN" [arg] ]
# ")" )
# ---------------------------
# "{"
# "{" {
# ---------------------------
# "}"
# "}" }
# ---------------------------
# "int"
# [block] --> ["{" "}" ]
# [func_body] --> [[block] ]
# [func] --> [[type] "IDN" "(" [args] ")" [func_body] ]
# "int" int
# ---------------------------
# "IDN"
# [type] --> ["int" ]
# "IDN" main
# ---------------------------
# "("
# "(" (
# ---------------------------
# ")"
# ")" )
# ---------------------------
# "{"
# "{" {
# ---------------------------
# "int"
# "int" int
# ---------------------------
# "IDN"
# [type] --> ["int" ]
# "IDN" a
# ---------------------------
# "="
# "=" =
# ---------------------------
# "INT10"
# "INT10" 10
# ---------------------------
# ","
# [num_const] --> ["INT10" ]
# [const] --> [[num_const] ]
# [factor] --> [[const] ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [expression] --> [[value] ]
# [init] --> ["=" [expression] ]
# "," ,
# ---------------------------
# "IDN"
# "IDN" b
# ---------------------------
# "="
# "=" =
# ---------------------------
# "INT10"
# "INT10" 10
# ---------------------------
# ";"
# [num_const] --> ["INT10" ]
# [const] --> [[num_const] ]
# [factor] --> [[const] ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [expression] --> [[value] ]
# [init] --> ["=" [expression] ]
# [vars] --> ["," "IDN" [init] ]
# ";" ;
# ---------------------------
# "if"
# [define_stmt] --> [[type] "IDN" [init] [vars] ";" ]
# [define_stmts] --> [[define_stmt] ]
# "if" if
# ---------------------------
# "("
# "(" (
# ---------------------------
# "IDN"
# "IDN" a
# ---------------------------
# "<"
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# "<" <
# ---------------------------
# "IDN"
# [compare_op] --> ["<" ]
# "IDN" b
# ---------------------------
# ")"
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [operation] --> [[compare_op] [value] ]
# [expression] --> [[value] [operation] ]
# [logical_expression] --> [[expression] ]
# ")" )
# ---------------------------
# "{"
# "{" {
# ---------------------------
# "int"
# Failed
# "int" int
# ---------------------------
# "IDN"
# "IDN" tmp
# ---------------------------
# "="
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# "=" =
# ---------------------------
# "IDN"
# [equal_op] --> ["=" ]
# "IDN" b
# ---------------------------
# ";"
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [operation] --> [[equal_op] [value] ]
# [expression] --> [[value] [operation] ]
# ";" ;
# ---------------------------
# "IDN"
# [assign_stmt] --> [[expression] ";" ]
# [stmt] --> [[assign_stmt] ]
# "IDN" b
# ---------------------------
# "="
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# "=" =
# ---------------------------
# "IDN"
# [equal_op] --> ["=" ]
# "IDN" a
# ---------------------------
# ";"
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [operation] --> [[equal_op] [value] ]
# [expression] --> [[value] [operation] ]
# ";" ;
# ---------------------------
# "IDN"
# [assign_stmt] --> [[expression] ";" ]
# [stmt] --> [[assign_stmt] ]
# "IDN" a
# ---------------------------
# "="
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# "=" =
# ---------------------------
# "IDN"
# [equal_op] --> ["=" ]
# "IDN" b
# ---------------------------
# ";"
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [operation] --> [[equal_op] [value] ]
# [expression] --> [[value] [operation] ]
# ";" ;
# ---------------------------
# "}"
# [assign_stmt] --> [[expression] ";" ]
# [stmt] --> [[assign_stmt] ]
# [stmts] --> [[stmt] ]
# [stmts] --> [[stmt] [stmts] ]
# [stmts] --> [[stmt] [stmts] ]
# "}" }
# ---------------------------
# "IDN"
# [block_stmt] --> ["{" [stmts] "}" ]
# [branch_stmt] --> ["if" "(" [logical_expression] ")" [block_stmt] ]
# [stmt] --> [[branch_stmt] ]
# "IDN" func
# ---------------------------
# "("
# "(" (
# ---------------------------
# "IDN"
# "IDN" a
# ---------------------------
# ","
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [expression] --> [[value] ]
# [isnull_expr] --> [[expression] ]
# "," ,
# ---------------------------
# "IDN"
# "IDN" b
# ---------------------------
# ")"
# [factor] --> ["IDN" ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [expression] --> [[value] ]
# [isnull_expr] --> [[expression] ]
# [isnull_es] --> ["," [isnull_expr] ]
# [es] --> [[isnull_expr] [isnull_es] ]
# ")" )
# ---------------------------
# ";"
# [call_func] --> ["(" [es] ")" ]
# [factor] --> ["IDN" [call_func] ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [expression] --> [[value] ]
# ";" ;
# ---------------------------
# "return"
# [assign_stmt] --> [[expression] ";" ]
# [stmt] --> [[assign_stmt] ]
# "return" return
# ---------------------------
# "INT10"
# "INT10" 0
# ---------------------------
# ";"
# [num_const] --> ["INT10" ]
# [const] --> [[num_const] ]
# [factor] --> [[const] ]
# [item] --> [[factor] ]
# [value] --> [[item] ]
# [expression] --> [[value] ]
# [isnull_expr] --> [[expression] ]
# ";" ;
# ---------------------------
# "}"
# [jump_stmt] --> ["return" [isnull_expr] ";" ]
# [stmt] --> [[jump_stmt] ]
# [stmts] --> [[stmt] ]
# [stmts] --> [[stmt] [stmts] ]
# [stmts] --> [[stmt] [stmts] ]
# "}" }
# ---------------------------
# "#"
# [block] --> ["{" [define_stmts] [stmts] "}" ]
# [func_body] --> [[block] ]
# [func] --> [[type] "IDN" "(" ")" [func_body] ]
# [funcs] --> [[func] ]
# [S] --> [[func] [funcs] ]
# OK
# "#"
